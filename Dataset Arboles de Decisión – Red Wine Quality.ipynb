# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
#Cargamos el dataset y mostramos las 5 primeras filas
data = pd.read_csv("winequality-red.csv")
data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
plt.hist(data.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x = "fixed acidity", y = "volatile acidity", hue = "quality", data = data)
# Out:
# <Axes: xlabel='fixed acidity', ylabel='pH'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar']])
plt.xticks(rotation=45)
plt.title('Boxplot Red Wine Quality')
plt.ylabel('Valores')
plt.show()

# %%
predictors_col = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar"]
target_col = ['quality']

# %%
predictors = data[predictors_col]
target = data[target_col]

# %%
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar
# 0               7.4             0.700         0.00             1.9
# 1               7.8             0.880         0.00             2.6
# 2               7.8             0.760         0.04             2.3
# 3              11.2             0.280         0.56             1.9
# 4               7.4             0.700         0.00             1.9
# ...             ...               ...          ...             ...
# 1594            6.2             0.600         0.08             2.0
# 1595            5.9             0.550         0.10             2.2
# 1596            6.3             0.510         0.13             2.3
# 1597            5.9             0.645         0.12             2.0
# 1598            6.0             0.310         0.47             3.6
#
# [1599 rows x 4 columns]

# %%
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
corr = predictors.corr()
corr
# Out:
#                   fixed acidity  volatile acidity  citric acid  residual sugar
# fixed acidity          1.000000         -0.256131     0.671703        0.114777
# volatile acidity      -0.256131          1.000000    -0.552496        0.001918
# citric acid            0.671703         -0.552496     1.000000        0.143577
# residual sugar         0.114777          0.001918     0.143577        1.000000

# %%
sns.heatmap(corr)
plt.title('Matriz de Correlación')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.2, random_state=13)

# %%
tree = DecisionTreeClassifier()

# %%
arbol = tree.fit(X_train, y_train)

# %%
plot_tree(arbol)
# Out:
# [Text(0.5048417110981613, 0.9833333333333333, 'x[1] <= 0.548\ngini = 0.646\nsamples = 1279\nvalue = [9.0, 45.0, 535.0, 514.0, 164.0, 12.0]'),
#  Text(0.19269051988933425, 0.95, 'x[1] <= 0.317\ngini = 0.649\nsamples = 699\nvalue = [1, 14, 210, 331, 133, 10]'),
#  Text(0.038624085047054724, 0.9166666666666666, 'x[3] <= 1.65\ngini = 0.597\nsamples = 145\nvalue = [0, 1, 15, 73, 54, 2]'),
#  Text(0.0055768560474032764, 0.8833333333333333, 'x[2] <= 0.23\ngini = 0.34\nsamples = 20\nvalue = [0, 0, 2, 16, 2, 0]'),
#  Text(0.0027884280237016382, 0.85, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.008365284071104914, 0.85, 'x[3] <= 1.55\ngini = 0.277\nsamples = 19\nvalue = [0, 0, 2, 16, 1, 0]'),
#  Text(0.0055768560474032764, 0.8166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.011153712094806553, 0.8166666666666667, 'x[2] <= 0.38\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 2, 6, 1, 0]'),
#  Text(0.008365284071104914, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.013942140118508192, 0.7833333333333333, 'x[0] <= 7.45\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.011153712094806553, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.01673056814220983, 0.75, 'x[2] <= 0.495\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.013942140118508192, 0.7166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.01951899616591147, 0.7166666666666667, 'x[1] <= 0.295\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.01673056814220983, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.022307424189613106, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07167131404670617, 0.8833333333333333, 'x[0] <= 7.8\ngini = 0.608\nsamples = 125\nvalue = [0, 1, 13, 57, 52, 2]'),
#  Text(0.04217497385848728, 0.85, 'x[2] <= 0.36\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 1, 15, 4, 0]'),
#  Text(0.03938654583478564, 0.8166666666666667, 'x[1] <= 0.265\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 1, 5, 4, 0]'),
#  Text(0.033809689787382365, 0.7833333333333333, 'x[0] <= 6.45\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.031021261763680724, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.036598117811084, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.04496340188218892, 0.7833333333333333, 'x[3] <= 1.85\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.04217497385848728, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04775182990589055, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.04496340188218892, 0.8166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.10116765423492506, 0.85, 'x[2] <= 0.325\ngini = 0.618\nsamples = 105\nvalue = [0, 1, 12, 42, 48, 2]'),
#  Text(0.09837922621122343, 0.8166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.1039560822586267, 0.8166666666666667, 'x[0] <= 11.15\ngini = 0.618\nsamples = 100\nvalue = [0, 1, 12, 37, 48, 2]'),
#  Text(0.07964447542697804, 0.7833333333333333, 'x[3] <= 2.525\ngini = 0.63\nsamples = 81\nvalue = [0, 1, 12, 26, 40, 2]'),
#  Text(0.05332868595329383, 0.75, 'x[2] <= 0.365\ngini = 0.59\nsamples = 64\nvalue = [0, 1, 6, 22, 34, 1]'),
#  Text(0.03067270826071802, 0.7166666666666667, 'x[0] <= 9.3\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 0, 2, 10, 0]'),
#  Text(0.027884280237016383, 0.6833333333333333, 'x[3] <= 1.95\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 1, 10, 0]'),
#  Text(0.025095852213314743, 0.65, 'x[0] <= 8.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.022307424189613106, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.027884280237016383, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.03067270826071802, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.03346113628441966, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.07598466364586964, 0.7166666666666667, 'x[0] <= 10.45\ngini = 0.625\nsamples = 52\nvalue = [0, 1, 6, 20, 24, 1]'),
#  Text(0.05995120250958522, 0.6833333333333333, 'x[0] <= 9.85\ngini = 0.648\nsamples = 43\nvalue = [0, 1, 6, 18, 17, 1]'),
#  Text(0.043220634367375395, 0.65, 'x[2] <= 0.445\ngini = 0.607\nsamples = 32\nvalue = [0, 0, 5, 11, 16, 0]'),
#  Text(0.03346113628441966, 0.6166666666666667, 'x[3] <= 1.85\ngini = 0.635\nsamples = 20\nvalue = [0, 0, 4, 9, 7, 0]'),
#  Text(0.027884280237016383, 0.5833333333333334, 'x[1] <= 0.295\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 0, 1, 0]'),
#  Text(0.025095852213314743, 0.55, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.03067270826071802, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.03903799233182294, 0.5833333333333334, 'x[2] <= 0.415\ngini = 0.539\nsamples = 16\nvalue = [0, 0, 1, 9, 6, 0]'),
#  Text(0.0362495643081213, 0.55, 'x[0] <= 8.5\ngini = 0.562\nsamples = 11\nvalue = [0, 0, 1, 4, 6, 0]'),
#  Text(0.03346113628441966, 0.5166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.03903799233182294, 0.5166666666666667, 'x[0] <= 8.95\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 1, 4, 1, 0]'),
#  Text(0.0362495643081213, 0.48333333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.04182642035552457, 0.48333333333333334, 'x[0] <= 9.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.03903799233182294, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.04461484837922621, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.04182642035552457, 0.55, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.052980132450331126, 0.6166666666666667, 'x[2] <= 0.565\ngini = 0.403\nsamples = 12\nvalue = [0, 0, 1, 2, 9, 0]'),
#  Text(0.050191704426629485, 0.5833333333333334, 'x[0] <= 7.95\ngini = 0.298\nsamples = 11\nvalue = [0, 0, 0, 2, 9, 0]'),
#  Text(0.04740327640292785, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.052980132450331126, 0.55, 'x[1] <= 0.245\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 1, 9, 0]'),
#  Text(0.050191704426629485, 0.5166666666666667, 'x[1] <= 0.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3, 0]'),
#  Text(0.04740327640292785, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.052980132450331126, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.055768560474032766, 0.5166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.055768560474032766, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.07668177065179504, 0.65, 'x[1] <= 0.245\ngini = 0.562\nsamples = 11\nvalue = [0, 1, 1, 7, 1, 1]'),
#  Text(0.06692227256883931, 0.6166666666666667, 'x[0] <= 10.3\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 1, 0]'),
#  Text(0.06134541652143604, 0.5833333333333334, 'x[2] <= 0.43\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.0585569884977344, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.06413384454513768, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.0724991286162426, 0.5833333333333334, 'x[2] <= 0.475\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.06971070059254096, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07528755663994423, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08644126873475079, 0.6166666666666667, 'x[0] <= 10.05\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 1]'),
#  Text(0.08365284071104914, 0.5833333333333334, 'x[0] <= 9.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.08086441268734751, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.08644126873475079, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.08922969675845242, 0.5833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.09201812478215406, 0.6833333333333333, 'x[3] <= 1.75\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 2, 7, 0]'),
#  Text(0.08922969675845242, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0948065528058557, 0.65, 'x[3] <= 2.15\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.09201812478215406, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.09759498082955734, 0.6166666666666667, 'x[0] <= 10.85\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.0948065528058557, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.10038340885325897, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.10596026490066225, 0.75, 'x[1] <= 0.255\ngini = 0.692\nsamples = 17\nvalue = [0, 0, 6, 4, 6, 1]'),
#  Text(0.10317183687696062, 0.7166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.10874869292436389, 0.7166666666666667, 'x[3] <= 3.55\ngini = 0.622\nsamples = 14\nvalue = [0, 0, 6, 1, 6, 1]'),
#  Text(0.10317183687696062, 0.6833333333333333, 'x[1] <= 0.295\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 6, 0, 2, 1]'),
#  Text(0.10038340885325897, 0.65, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.10596026490066225, 0.65, 'x[1] <= 0.305\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 0, 2, 1]'),
#  Text(0.10317183687696062, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.10874869292436389, 0.6166666666666667, 'x[2] <= 0.38\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.10596026490066225, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11153712094806553, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.11432554897176717, 0.6833333333333333, 'x[2] <= 0.475\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 1, 4, 0]'),
#  Text(0.11153712094806553, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1171139769954688, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.12826768909027536, 0.7833333333333333, 'x[0] <= 11.65\ngini = 0.488\nsamples = 19\nvalue = [0, 0, 0, 11, 8, 0]'),
#  Text(0.12547926106657373, 0.75, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.131056117113977, 0.75, 'x[3] <= 2.95\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 3, 8, 0]'),
#  Text(0.12826768909027536, 0.7166666666666667, 'x[1] <= 0.305\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 2, 8, 0]'),
#  Text(0.12547926106657373, 0.6833333333333333, 'x[0] <= 13.35\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 1, 8, 0]'),
#  Text(0.12269083304287208, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.12826768909027536, 0.65, 'x[0] <= 14.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.12547926106657373, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.131056117113977, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.131056117113977, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13384454513767863, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3467569547316138, 0.9166666666666666, 'x[3] <= 3.35\ngini = 0.638\nsamples = 554\nvalue = [1, 13, 195, 258, 79, 8]'),
#  Text(0.19926504226211222, 0.8833333333333333, 'x[3] <= 3.15\ngini = 0.617\nsamples = 483\nvalue = [1, 8, 173, 237, 57, 7]'),
#  Text(0.1964766142384106, 0.85, 'x[0] <= 5.55\ngini = 0.621\nsamples = 473\nvalue = [1, 8, 173, 227, 57, 7]'),
#  Text(0.1449982572324852, 0.8166666666666667, 'x[1] <= 0.38\ngini = 0.698\nsamples = 13\nvalue = [0, 1, 1, 3, 6, 2]'),
#  Text(0.13942140118508192, 0.7833333333333333, 'x[2] <= 0.125\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.13663297316138026, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.14220982920878356, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15057511327988846, 0.7833333333333333, 'x[1] <= 0.515\ngini = 0.58\nsamples = 10\nvalue = [0, 1, 0, 1, 6, 2]'),
#  Text(0.14778668525618682, 0.75, 'x[3] <= 2.25\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 1, 6, 2]'),
#  Text(0.1449982572324852, 0.7166666666666667, 'x[0] <= 5.45\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 0, 6, 2]'),
#  Text(0.14220982920878356, 0.6833333333333333, 'x[0] <= 5.05\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 0, 6, 1]'),
#  Text(0.13942140118508192, 0.65, 'x[3] <= 2.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1]'),
#  Text(0.13663297316138026, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.14220982920878356, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.1449982572324852, 0.65, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.14778668525618682, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.15057511327988846, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1533635413035901, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.247954971244336, 0.8166666666666667, 'x[2] <= 0.315\ngini = 0.61\nsamples = 460\nvalue = [1, 7, 172, 224, 51, 5]'),
#  Text(0.1751971505751133, 0.7833333333333333, 'x[3] <= 1.65\ngini = 0.551\nsamples = 213\nvalue = [0, 5, 84, 115, 8, 1]'),
#  Text(0.16172882537469502, 0.75, 'x[3] <= 1.45\ngini = 0.401\nsamples = 18\nvalue = [0, 0, 13, 5, 0, 0]'),
#  Text(0.15615196932729175, 0.7166666666666667, 'x[0] <= 6.15\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.1533635413035901, 0.6833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.15894039735099338, 0.6833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.16730568142209828, 0.7166666666666667, 'x[2] <= 0.19\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 1, 0, 0]'),
#  Text(0.16451725339839665, 0.6833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.17009410944579992, 0.6833333333333333, 'x[1] <= 0.435\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.16730568142209828, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.17288253746950158, 0.65, 'x[0] <= 6.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.17009410944579992, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1756709654932032, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.18866547577553155, 0.75, 'x[2] <= 0.025\ngini = 0.547\nsamples = 195\nvalue = [0, 5, 71, 110, 8, 1]'),
#  Text(0.17845939351690485, 0.7166666666666667, 'x[3] <= 2.15\ngini = 0.153\nsamples = 12\nvalue = [0, 1, 0, 11, 0, 0]'),
#  Text(0.1756709654932032, 0.6833333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.18124782154060648, 0.6833333333333333, 'x[1] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.17845939351690485, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1840362495643081, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19887155803415824, 0.7166666666666667, 'x[0] <= 5.8\ngini = 0.554\nsamples = 183\nvalue = [0.0, 4.0, 71.0, 99.0, 8.0, 1.0]'),
#  Text(0.1960831300104566, 0.6833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.20165998605785987, 0.6833333333333333, 'x[1] <= 0.345\ngini = 0.551\nsamples = 179\nvalue = [0, 4, 67, 99, 8, 1]'),
#  Text(0.1896131056117114, 0.65, 'x[3] <= 2.4\ngini = 0.42\nsamples = 10\nvalue = [0, 0, 7, 3, 0, 0]'),
#  Text(0.18682467758800975, 0.6166666666666667, 'x[0] <= 8.4\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.1840362495643081, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.1896131056117114, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19240153363541304, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.21370686650400836, 0.65, 'x[0] <= 6.65\ngini = 0.548\nsamples = 169\nvalue = [0, 4, 60, 96, 8, 1]'),
#  Text(0.1979783896828163, 0.6166666666666667, 'x[2] <= 0.27\ngini = 0.355\nsamples = 23\nvalue = [0, 0, 4, 18, 1, 0]'),
#  Text(0.19518996165911467, 0.5833333333333334, 'x[3] <= 1.85\ngini = 0.31\nsamples = 22\nvalue = [0, 0, 3, 18, 1, 0]'),
#  Text(0.1896131056117114, 0.55, 'x[1] <= 0.415\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 2, 3, 1, 0]'),
#  Text(0.18682467758800975, 0.5166666666666667, 'x[2] <= 0.155\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.1840362495643081, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.1896131056117114, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.19240153363541304, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.20076681770651794, 0.55, 'x[3] <= 2.35\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 1, 15, 0, 0]'),
#  Text(0.1979783896828163, 0.5166666666666667, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.20355524573021958, 0.5166666666666667, 'x[1] <= 0.485\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.20076681770651794, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.20634367375392124, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20076681770651794, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2294353433252004, 0.6166666666666667, 'x[2] <= 0.035\ngini = 0.564\nsamples = 146\nvalue = [0, 4, 56, 78, 7, 1]'),
#  Text(0.22664691530149877, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.23222377134890207, 0.5833333333333334, 'x[2] <= 0.075\ngini = 0.563\nsamples = 144\nvalue = [0, 4, 54, 78, 7, 1]'),
#  Text(0.2294353433252004, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.2350121993726037, 0.55, 'x[2] <= 0.095\ngini = 0.568\nsamples = 140\nvalue = [0, 4, 54, 74, 7, 1]'),
#  Text(0.21470895782502614, 0.5166666666666667, 'x[1] <= 0.515\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.2119205298013245, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.21749738584872777, 0.48333333333333334, 'x[1] <= 0.53\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.21470895782502614, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.22028581387242943, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25531544092018127, 0.5166666666666667, 'x[1] <= 0.543\ngini = 0.556\nsamples = 134\nvalue = [0, 4, 51, 73, 5, 1]'),
#  Text(0.2525270128964796, 0.48333333333333334, 'x[2] <= 0.295\ngini = 0.56\nsamples = 131\nvalue = [0, 4, 51, 70, 5, 1]'),
#  Text(0.2258626699198327, 0.45, 'x[0] <= 9.95\ngini = 0.552\nsamples = 101\nvalue = [0, 4, 43, 52, 2, 0]'),
#  Text(0.22307424189613106, 0.4166666666666667, 'x[0] <= 8.75\ngini = 0.554\nsamples = 99\nvalue = [0, 4, 43, 50, 2, 0]'),
#  Text(0.20320669222725687, 0.38333333333333336, 'x[0] <= 7.75\ngini = 0.544\nsamples = 89\nvalue = [0, 3, 36, 48, 2, 0]'),
#  Text(0.18856744510282328, 0.35, 'x[1] <= 0.535\ngini = 0.56\nsamples = 62\nvalue = [0, 3, 29, 29, 1, 0]'),
#  Text(0.18577901707912164, 0.31666666666666665, 'x[3] <= 2.25\ngini = 0.561\nsamples = 58\nvalue = [0, 3, 25, 29, 1, 0]'),
#  Text(0.17044266294876265, 0.2833333333333333, 'x[0] <= 7.25\ngini = 0.589\nsamples = 35\nvalue = [0, 3, 18, 13, 1, 0]'),
#  Text(0.15928895085395608, 0.25, 'x[3] <= 1.75\ngini = 0.568\nsamples = 18\nvalue = [0, 2, 6, 10, 0, 0]'),
#  Text(0.15650052283025445, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.16207737887765772, 0.21666666666666667, 'x[0] <= 7.15\ngini = 0.604\nsamples = 15\nvalue = [0, 2, 6, 7, 0, 0]'),
#  Text(0.15650052283025445, 0.18333333333333332, 'x[2] <= 0.185\ngini = 0.593\nsamples = 9\nvalue = [0, 2, 5, 2, 0, 0]'),
#  Text(0.15371209480655282, 0.15, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.15928895085395608, 0.15, 'x[2] <= 0.245\ngini = 0.667\nsamples = 6\nvalue = [0, 2, 2, 2, 0, 0]'),
#  Text(0.15650052283025445, 0.11666666666666667, 'x[0] <= 7.0\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 2, 0, 0]'),
#  Text(0.15371209480655282, 0.08333333333333333, 'x[1] <= 0.495\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.15092366678285116, 0.05, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.15650052283025445, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15928895085395608, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.16207737887765772, 0.11666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.16765423492506099, 0.18333333333333332, 'x[3] <= 2.15\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.16486580690135935, 0.15, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.17044266294876265, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.18159637504356918, 0.25, 'x[1] <= 0.365\ngini = 0.464\nsamples = 17\nvalue = [0, 1, 12, 3, 1, 0]'),
#  Text(0.17880794701986755, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.1843848030672708, 0.21666666666666667, 'x[0] <= 7.65\ngini = 0.398\nsamples = 16\nvalue = [0, 0, 12, 3, 1, 0]'),
#  Text(0.18159637504356918, 0.18333333333333332, 'x[2] <= 0.17\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 7, 3, 1, 0]'),
#  Text(0.1760195189961659, 0.15, 'x[2] <= 0.14\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.17323109097246428, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.17880794701986755, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.18717323109097248, 0.15, 'x[2] <= 0.185\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 6, 3, 0, 0]'),
#  Text(0.1843848030672708, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1899616591146741, 0.11666666666666667, 'x[2] <= 0.265\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.18717323109097248, 0.08333333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.19275008713837574, 0.08333333333333333, 'x[2] <= 0.28\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.1899616591146741, 0.05, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.19553851516207738, 0.05, 'x[1] <= 0.415\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.19275008713837574, 0.016666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.198326943185779, 0.016666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.18717323109097248, 0.18333333333333332, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.20111537120948064, 0.2833333333333333, 'x[3] <= 2.55\ngini = 0.423\nsamples = 23\nvalue = [0, 0, 7, 16, 0, 0]'),
#  Text(0.198326943185779, 0.25, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.2039037992331823, 0.25, 'x[0] <= 7.45\ngini = 0.497\nsamples = 13\nvalue = [0, 0, 7, 6, 0, 0]'),
#  Text(0.198326943185779, 0.21666666666666667, 'x[2] <= 0.215\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.19553851516207738, 0.18333333333333332, 'x[3] <= 2.65\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.19275008713837574, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.198326943185779, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.20111537120948064, 0.18333333333333332, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.20948065528058557, 0.21666666666666667, 'x[2] <= 0.13\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.20669222725688394, 0.18333333333333332, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2122690833042872, 0.18333333333333332, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.1913558731265249, 0.31666666666666665, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.21784593935169047, 0.35, 'x[1] <= 0.385\ngini = 0.436\nsamples = 27\nvalue = [0, 0, 7, 19, 1, 0]'),
#  Text(0.20948065528058557, 0.31666666666666665, 'x[0] <= 8.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.20669222725688394, 0.2833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2122690833042872, 0.2833333333333333, 'x[3] <= 2.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.20948065528058557, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.21505751132798884, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2262112234227954, 0.31666666666666665, 'x[2] <= 0.245\ngini = 0.34\nsamples = 23\nvalue = [0, 0, 5, 18, 0, 0]'),
#  Text(0.22342279539909377, 0.2833333333333333, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.22899965144649703, 0.2833333333333333, 'x[3] <= 1.95\ngini = 0.43\nsamples = 16\nvalue = [0, 0, 5, 11, 0, 0]'),
#  Text(0.22063436737539213, 0.25, 'x[1] <= 0.505\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.21784593935169047, 0.21666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.22342279539909377, 0.21666666666666667, 'x[0] <= 7.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.22063436737539213, 0.18333333333333332, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2262112234227954, 0.18333333333333332, 'x[0] <= 8.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.22342279539909377, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22899965144649703, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.23736493551760196, 0.25, 'x[1] <= 0.5\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.23457650749390033, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2401533635413036, 0.21666666666666667, 'x[3] <= 2.25\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.23736493551760196, 0.18333333333333332, 'x[0] <= 7.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.23457650749390033, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2401533635413036, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24294179156500523, 0.18333333333333332, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.24294179156500523, 0.38333333333333336, 'x[0] <= 9.4\ngini = 0.46\nsamples = 10\nvalue = [0, 1, 7, 2, 0, 0]'),
#  Text(0.23457650749390033, 0.35, 'x[1] <= 0.49\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.23178807947019867, 0.31666666666666665, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.23736493551760196, 0.31666666666666665, 'x[0] <= 9.05\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.23457650749390033, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2401533635413036, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.25130707563611016, 0.35, 'x[2] <= 0.25\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 1, 0, 0]'),
#  Text(0.2485186476124085, 0.31666666666666665, 'x[1] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.24573021958870686, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25130707563611016, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.25409550365981176, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22865109794353433, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.27919135587312655, 0.45, 'x[3] <= 2.225\ngini = 0.558\nsamples = 30\nvalue = [0, 0, 8, 18, 3, 1]'),
#  Text(0.26803764377831996, 0.4166666666666667, 'x[1] <= 0.37\ngini = 0.377\nsamples = 18\nvalue = [0, 0, 2, 14, 1, 1]'),
#  Text(0.2596723597072151, 0.38333333333333336, 'x[3] <= 1.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.2568839316835134, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2624607877309167, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.2764029278494249, 0.38333333333333336, 'x[3] <= 2.05\ngini = 0.32\nsamples = 16\nvalue = [0, 0, 2, 13, 1, 0]'),
#  Text(0.26803764377831996, 0.35, 'x[0] <= 7.95\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.26524921575461835, 0.31666666666666665, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2708260718020216, 0.31666666666666665, 'x[1] <= 0.395\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.26803764377831996, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2736144998257232, 0.2833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2847682119205298, 0.35, 'x[0] <= 7.55\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 3, 1, 0]'),
#  Text(0.28197978389682815, 0.31666666666666665, 'x[3] <= 2.15\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(0.27919135587312655, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2847682119205298, 0.2833333333333333, 'x[0] <= 7.2\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.28197978389682815, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2875566399442314, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2875566399442314, 0.31666666666666665, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.2903450679679331, 0.4166666666666667, 'x[3] <= 2.35\ngini = 0.611\nsamples = 12\nvalue = [0, 0, 6, 4, 2, 0]'),
#  Text(0.2875566399442314, 0.38333333333333336, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.29313349599163474, 0.38333333333333336, 'x[0] <= 8.1\ngini = 0.642\nsamples = 9\nvalue = [0, 0, 3, 4, 2, 0]'),
#  Text(0.2903450679679331, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.29592192401533635, 0.35, 'x[1] <= 0.415\ngini = 0.653\nsamples = 7\nvalue = [0, 0, 3, 2, 2, 0]'),
#  Text(0.29313349599163474, 0.31666666666666665, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.298710352039038, 0.31666666666666665, 'x[1] <= 0.475\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 2, 1, 0]'),
#  Text(0.29592192401533635, 0.2833333333333333, 'x[1] <= 0.465\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.29313349599163474, 0.25, 'x[3] <= 2.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.2903450679679331, 0.21666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.29592192401533635, 0.21666666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.298710352039038, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3014987800627396, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2581038689438829, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3207127919135587, 0.7833333333333333, 'x[0] <= 7.35\ngini = 0.648\nsamples = 247\nvalue = [1, 2, 88, 109, 43, 4]'),
#  Text(0.26664342976646915, 0.75, 'x[1] <= 0.375\ngini = 0.635\nsamples = 21\nvalue = [0, 0, 5, 6, 10, 0]'),
#  Text(0.2554897176716626, 0.7166666666666667, 'x[2] <= 0.465\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 2, 1, 8, 0]'),
#  Text(0.24991286162425932, 0.6833333333333333, 'x[3] <= 2.45\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 0, 8, 0]'),
#  Text(0.2471244336005577, 0.65, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.25270128964796096, 0.65, 'x[2] <= 0.325\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.24991286162425932, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2554897176716626, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2610665737190659, 0.6833333333333333, 'x[2] <= 0.48\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2582781456953642, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2638550017427675, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2777971418612757, 0.7166666666666667, 'x[2] <= 0.38\ngini = 0.62\nsamples = 10\nvalue = [0, 0, 3, 5, 2, 0]'),
#  Text(0.2722202858138724, 0.6833333333333333, 'x[1] <= 0.425\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 1, 1, 0]'),
#  Text(0.2694318577901708, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2750087138375741, 0.65, 'x[3] <= 1.85\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.2722202858138724, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2777971418612757, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.283373997908679, 0.6833333333333333, 'x[0] <= 6.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.28058556988497735, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2861624259323806, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.3747821540606483, 0.75, 'x[1] <= 0.375\ngini = 0.636\nsamples = 226\nvalue = [1, 2, 83, 103, 33, 4]'),
#  Text(0.3210177762286511, 0.7166666666666667, 'x[0] <= 8.45\ngini = 0.611\nsamples = 72\nvalue = [0, 0, 18, 39, 13, 2]'),
#  Text(0.29452771000348554, 0.6833333333333333, 'x[3] <= 2.65\ngini = 0.459\nsamples = 22\nvalue = [0.0, 0.0, 1.0, 15.0, 6.0, 0.0]'),
#  Text(0.2917392819797839, 0.65, 'x[3] <= 2.35\ngini = 0.395\nsamples = 20\nvalue = [0, 0, 1, 15, 4, 0]'),
#  Text(0.2889508539560823, 0.6166666666666667, 'x[0] <= 7.6\ngini = 0.5\nsamples = 14\nvalue = [0, 0, 1, 9, 4, 0]'),
#  Text(0.2861624259323806, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2917392819797839, 0.5833333333333334, 'x[3] <= 2.25\ngini = 0.462\nsamples = 13\nvalue = [0, 0, 1, 9, 3, 0]'),
#  Text(0.2847682119205298, 0.55, 'x[3] <= 1.65\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 1, 8, 1, 0]'),
#  Text(0.27919135587312655, 0.5166666666666667, 'x[2] <= 0.425\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2764029278494249, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.28197978389682815, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2903450679679331, 0.5166666666666667, 'x[3] <= 1.95\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.2875566399442314, 0.48333333333333334, 'x[2] <= 0.365\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.2847682119205298, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.2903450679679331, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.29313349599163474, 0.48333333333333334, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.298710352039038, 0.55, 'x[0] <= 8.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.29592192401533635, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3014987800627396, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.29452771000348554, 0.6166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.29731613802718715, 0.65, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.34750784245381666, 0.6833333333333333, 'x[2] <= 0.635\ngini = 0.633\nsamples = 50\nvalue = [0.0, 0.0, 17.0, 24.0, 7.0, 2.0]'),
#  Text(0.344719414430115, 0.65, 'x[3] <= 2.15\ngini = 0.656\nsamples = 44\nvalue = [0, 0, 17, 18, 7, 2]'),
#  Text(0.32241199024050193, 0.6166666666666667, 'x[2] <= 0.475\ngini = 0.505\nsamples = 20\nvalue = [0, 0, 5, 13, 2, 0]'),
#  Text(0.3154409201812478, 0.5833333333333334, 'x[0] <= 8.8\ngini = 0.314\nsamples = 11\nvalue = [0, 0, 1, 9, 1, 0]'),
#  Text(0.30986406413384454, 0.55, 'x[3] <= 1.75\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3070756361101429, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3126524921575462, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3210177762286511, 0.55, 'x[3] <= 1.55\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 0, 8, 1, 0]'),
#  Text(0.31822934820494947, 0.5166666666666667, 'x[1] <= 0.355\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.3154409201812478, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3210177762286511, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.32380620425235274, 0.5166666666666667, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.329383060299756, 0.5833333333333334, 'x[2] <= 0.49\ngini = 0.593\nsamples = 9\nvalue = [0, 0, 4, 4, 1, 0]'),
#  Text(0.3265946322760544, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.33217148832345766, 0.55, 'x[0] <= 9.15\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 4, 4, 0, 0]'),
#  Text(0.329383060299756, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.33495991634715927, 0.5166666666666667, 'x[1] <= 0.335\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.329383060299756, 0.48333333333333334, 'x[2] <= 0.565\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.3265946322760544, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.33217148832345766, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3405367723945626, 0.48333333333333334, 'x[0] <= 9.7\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.33774834437086093, 0.45, 'gini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3433252004182642, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3670268386197281, 0.6166666666666667, 'x[0] <= 11.9\ngini = 0.656\nsamples = 24\nvalue = [0, 0, 12, 5, 5, 2]'),
#  Text(0.36423841059602646, 0.5833333333333334, 'x[1] <= 0.335\ngini = 0.599\nsamples = 21\nvalue = [0, 0, 12, 2, 5, 2]'),
#  Text(0.3572673405367724, 0.55, 'x[0] <= 10.2\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 3, 1, 4, 0]'),
#  Text(0.35447891251307073, 0.5166666666666667, 'x[3] <= 2.7\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 3, 1, 2, 0]'),
#  Text(0.3516904844893691, 0.48333333333333334, 'x[2] <= 0.53\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 0, 2, 0]'),
#  Text(0.34890205646566747, 0.45, 'x[2] <= 0.41\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.34611362844196586, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3516904844893691, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.35447891251307073, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3572673405367724, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.36005576856047405, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3712094806552806, 0.55, 'x[0] <= 10.65\ngini = 0.485\nsamples = 13\nvalue = [0, 0, 9, 1, 1, 2]'),
#  Text(0.3656326246078773, 0.5166666666666667, 'x[2] <= 0.355\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 8, 1, 1, 0]'),
#  Text(0.36284419658417566, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3684210526315789, 0.48333333333333334, 'x[0] <= 10.4\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.3656326246078773, 0.45, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.3712094806552806, 0.45, 'x[0] <= 10.55\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.3684210526315789, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37399790867898225, 0.4166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.37678633670268386, 0.5166666666666667, 'x[3] <= 2.85\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 0, 2]'),
#  Text(0.37399790867898225, 0.48333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.3795747647263855, 0.48333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3698152666434298, 0.5833333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3502962704775183, 0.65, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.4285465318926455, 0.7166666666666667, 'x[2] <= 0.335\ngini = 0.632\nsamples = 154\nvalue = [1.0, 2.0, 65.0, 64.0, 20.0, 2.0]'),
#  Text(0.42575810386894386, 0.6833333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.4313349599163472, 0.6833333333333333, 'x[0] <= 10.05\ngini = 0.637\nsamples = 144\nvalue = [1, 2, 55, 64, 20, 2]'),
#  Text(0.4151272220285814, 0.65, 'x[2] <= 0.62\ngini = 0.604\nsamples = 74\nvalue = [0, 1, 35, 30, 6, 2]'),
#  Text(0.41233879400487977, 0.6166666666666667, 'x[2] <= 0.515\ngini = 0.613\nsamples = 69\nvalue = [0, 1, 30, 30, 6, 2]'),
#  Text(0.40536772394562565, 0.5833333333333334, 'x[2] <= 0.495\ngini = 0.608\nsamples = 64\nvalue = [0, 1, 30, 26, 5, 2]'),
#  Text(0.3997908678982224, 0.55, 'x[3] <= 2.85\ngini = 0.591\nsamples = 60\nvalue = [0, 1, 28, 26, 3, 2]'),
#  Text(0.3970024398745207, 0.5166666666666667, 'x[0] <= 7.45\ngini = 0.595\nsamples = 57\nvalue = [0, 1, 25, 26, 3, 2]'),
#  Text(0.3942140118508191, 0.48333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3997908678982224, 0.48333333333333334, 'x[0] <= 9.05\ngini = 0.597\nsamples = 54\nvalue = [0, 1, 22, 26, 3, 2]'),
#  Text(0.3865458347856396, 0.45, 'x[2] <= 0.46\ngini = 0.587\nsamples = 29\nvalue = [0, 1, 7, 17, 2, 2]'),
#  Text(0.3795747647263855, 0.4166666666666667, 'x[1] <= 0.385\ngini = 0.5\nsamples = 22\nvalue = [0.0, 0.0, 3.0, 15.0, 2.0, 2.0]'),
#  Text(0.37399790867898225, 0.38333333333333336, 'x[0] <= 8.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.3712094806552806, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37678633670268386, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3851516207737888, 0.38333333333333336, 'x[1] <= 0.53\ngini = 0.421\nsamples = 19\nvalue = [0, 0, 3, 14, 0, 2]'),
#  Text(0.3823631927500871, 0.35, 'x[3] <= 2.35\ngini = 0.364\nsamples = 18\nvalue = [0, 0, 3, 14, 0, 1]'),
#  Text(0.3795747647263855, 0.31666666666666665, 'x[3] <= 2.25\ngini = 0.512\nsamples = 11\nvalue = [0, 0, 3, 7, 0, 1]'),
#  Text(0.37678633670268386, 0.2833333333333333, 'x[0] <= 8.45\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 2, 7, 0, 1]'),
#  Text(0.37399790867898225, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3795747647263855, 0.25, 'x[0] <= 8.85\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 2, 4, 0, 1]'),
#  Text(0.37678633670268386, 0.21666666666666667, 'x[3] <= 1.45\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(0.37399790867898225, 0.18333333333333332, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3795747647263855, 0.18333333333333332, 'x[0] <= 8.7\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 0, 1]'),
#  Text(0.37678633670268386, 0.15, 'x[2] <= 0.385\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.37399790867898225, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3795747647263855, 0.11666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.3823631927500871, 0.15, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3823631927500871, 0.21666666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.3823631927500871, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3851516207737888, 0.31666666666666665, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.3879400487974904, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.3935169048448937, 0.4166666666666667, 'x[0] <= 7.8\ngini = 0.571\nsamples = 7\nvalue = [0, 1, 4, 2, 0, 0]'),
#  Text(0.39072847682119205, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3963053328685953, 0.38333333333333336, 'x[1] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.3935169048448937, 0.35, 'x[0] <= 8.4\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.39072847682119205, 0.31666666666666665, 'x[0] <= 8.15\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3879400487974904, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3935169048448937, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3963053328685953, 0.31666666666666665, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.399093760892297, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4130359010108052, 0.45, 'x[2] <= 0.345\ngini = 0.509\nsamples = 25\nvalue = [0, 0, 15, 9, 1, 0]'),
#  Text(0.4102474729871035, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4158243290345068, 0.4166666666666667, 'x[2] <= 0.455\ngini = 0.469\nsamples = 24\nvalue = [0, 0, 15, 9, 0, 0]'),
#  Text(0.4102474729871035, 0.38333333333333336, 'x[2] <= 0.425\ngini = 0.401\nsamples = 18\nvalue = [0, 0, 13, 5, 0, 0]'),
#  Text(0.4074590449634019, 0.35, 'x[3] <= 2.15\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.4018821889159986, 0.31666666666666665, 'x[0] <= 9.8\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.399093760892297, 0.2833333333333333, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.40467061693970025, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4130359010108052, 0.31666666666666665, 'x[1] <= 0.52\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.4102474729871035, 0.2833333333333333, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.4158243290345068, 0.2833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4130359010108052, 0.35, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.42140118508191005, 0.38333333333333336, 'x[0] <= 9.55\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.41861275705820844, 0.35, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4241896131056117, 0.35, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.40257929592192404, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4109445799930289, 0.55, 'x[3] <= 2.25\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0]'),
#  Text(0.4081561519693273, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4137330080167306, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.41930986406413384, 0.5833333333333334, 'x[0] <= 9.8\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.4165214360404322, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4220982920878355, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.41791565005228304, 0.6166666666666667, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.44754269780411293, 0.65, 'x[0] <= 10.25\ngini = 0.642\nsamples = 70\nvalue = [1, 1, 20, 34, 14, 0]'),
#  Text(0.43325200418264204, 0.6166666666666667, 'x[3] <= 2.3\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
# ...
#  Text(0.7748344370860927, 0.45, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.7831997211571976, 0.48333333333333334, 'x[3] <= 3.95\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.780411293133496, 0.45, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.7859881491808993, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7831997211571976, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7831997211571976, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7859881491808993, 0.6166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.7943534332520041, 0.65, 'x[2] <= 0.115\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 4, 7, 0, 0]'),
#  Text(0.7915650052283025, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7971418612757059, 0.6166666666666667, 'x[3] <= 2.0\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.7943534332520041, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7999302892994075, 0.5833333333333334, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8174886720111537, 0.6833333333333333, 'x[3] <= 1.55\ngini = 0.295\nsamples = 86\nvalue = [0, 2, 71, 13, 0, 0]'),
#  Text(0.8069013593586616, 0.65, 'x[2] <= 0.205\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.8041129313349599, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8096897873823632, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8280759846636458, 0.65, 'x[2] <= 0.215\ngini = 0.251\nsamples = 83\nvalue = [0, 1, 71, 11, 0, 0]'),
#  Text(0.8152666434297665, 0.6166666666666667, 'x[0] <= 6.75\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.8124782154060648, 0.5833333333333334, 'x[1] <= 0.625\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.8096897873823632, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8152666434297665, 0.55, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8180550714534681, 0.5833333333333334, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.8408853258975253, 0.6166666666666667, 'x[0] <= 8.75\ngini = 0.301\nsamples = 61\nvalue = [0, 1, 50, 10, 0, 0]'),
#  Text(0.8295573370512374, 0.5833333333333334, 'x[0] <= 8.45\ngini = 0.361\nsamples = 44\nvalue = [0, 1, 34, 9, 0, 0]'),
#  Text(0.8208434994771697, 0.55, 'x[0] <= 8.05\ngini = 0.302\nsamples = 39\nvalue = [0, 1, 32, 6, 0, 0]'),
#  Text(0.8117811084001394, 0.5166666666666667, 'x[0] <= 7.85\ngini = 0.355\nsamples = 26\nvalue = [0, 0, 20, 6, 0, 0]'),
#  Text(0.8020216103171837, 0.48333333333333334, 'x[1] <= 0.575\ngini = 0.255\nsamples = 20\nvalue = [0, 0, 17, 3, 0, 0]'),
#  Text(0.7964447542697805, 0.45, 'x[0] <= 7.0\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.7936563262460787, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7992331822934821, 0.4166666666666667, 'x[0] <= 7.45\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.7964447542697805, 0.38333333333333336, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8020216103171837, 0.38333333333333336, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.807598466364587, 0.45, 'x[3] <= 2.05\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 15, 1, 0, 0]'),
#  Text(0.8048100383408854, 0.4166666666666667, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.8103868943882886, 0.4166666666666667, 'x[2] <= 0.245\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.807598466364587, 0.38333333333333336, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.8131753224119902, 0.38333333333333336, 'x[0] <= 7.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8103868943882886, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8159637504356919, 0.35, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8215406064830951, 0.48333333333333334, 'x[3] <= 3.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.8187521784593935, 0.45, 'x[3] <= 2.2\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.8159637504356919, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8215406064830951, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8243290345067968, 0.45, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8299058905542, 0.5166666666666667, 'x[2] <= 0.255\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0, 0, 0]'),
#  Text(0.8271174625304984, 0.48333333333333334, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.8326943185779017, 0.48333333333333334, 'x[0] <= 8.25\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8299058905542, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8354827466016034, 0.45, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.838271174625305, 0.55, 'x[1] <= 0.713\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 2, 3, 0, 0]'),
#  Text(0.8354827466016034, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8410596026490066, 0.5166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8522133147438131, 0.5833333333333334, 'x[2] <= 0.225\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 16, 1, 0, 0]'),
#  Text(0.8494248867201115, 0.55, 'x[1] <= 0.777\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8466364586964099, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8522133147438131, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8550017427675148, 0.55, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.8731265249215755, 0.7166666666666667, 'x[1] <= 0.615\ngini = 0.526\nsamples = 35\nvalue = [0, 1, 16, 18, 0, 0]'),
#  Text(0.8633670268386198, 0.6833333333333333, 'x[3] <= 2.75\ngini = 0.508\nsamples = 16\nvalue = [0, 1, 10, 5, 0, 0]'),
#  Text(0.8577901707912164, 0.65, 'x[2] <= 0.295\ngini = 0.278\nsamples = 12\nvalue = [0, 0, 10, 2, 0, 0]'),
#  Text(0.8550017427675148, 0.6166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.860578598814918, 0.6166666666666667, 'x[3] <= 2.25\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.8577901707912164, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8633670268386198, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.868943882886023, 0.65, 'x[1] <= 0.595\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.8661554548623214, 0.6166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8717323109097247, 0.6166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8828860230045312, 0.6833333333333333, 'x[3] <= 4.25\ngini = 0.432\nsamples = 19\nvalue = [0, 0, 6, 13, 0, 0]'),
#  Text(0.8800975949808295, 0.65, 'x[0] <= 9.5\ngini = 0.305\nsamples = 16\nvalue = [0, 0, 3, 13, 0, 0]'),
#  Text(0.8773091669571279, 0.6166666666666667, 'x[3] <= 3.4\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 1, 13, 0, 0]'),
#  Text(0.8745207389334263, 0.5833333333333334, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 0, 12, 0, 0]'),
#  Text(0.8800975949808295, 0.5833333333333334, 'x[3] <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8773091669571279, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8828860230045312, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8828860230045312, 0.6166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8856744510282328, 0.65, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9024050191704427, 0.75, 'x[0] <= 9.75\ngini = 0.304\nsamples = 29\nvalue = [0, 2, 24, 2, 1, 0]'),
#  Text(0.899616591146741, 0.7166666666666667, 'x[0] <= 7.45\ngini = 0.255\nsamples = 28\nvalue = [0, 2, 24, 2, 0, 0]'),
#  Text(0.8940397350993378, 0.6833333333333333, 'x[1] <= 0.632\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.8912513070756362, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8968281631230394, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9051934471941443, 0.6833333333333333, 'x[3] <= 2.05\ngini = 0.21\nsamples = 26\nvalue = [0, 1, 23, 2, 0, 0]'),
#  Text(0.9024050191704427, 0.65, 'x[0] <= 8.8\ngini = 0.379\nsamples = 13\nvalue = [0, 1, 10, 2, 0, 0]'),
#  Text(0.8968281631230394, 0.6166666666666667, 'x[2] <= 0.39\ngini = 0.18\nsamples = 10\nvalue = [0, 1, 9, 0, 0, 0]'),
#  Text(0.8940397350993378, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.899616591146741, 0.5833333333333334, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.9079818752178459, 0.6166666666666667, 'x[2] <= 0.495\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.9051934471941443, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9107703032415476, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9079818752178459, 0.65, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.9051934471941443, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9163471592889508, 0.7833333333333333, 'x[1] <= 0.835\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.9135587312652492, 0.75, 'x[2] <= 0.255\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9107703032415476, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9163471592889508, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9191355873126525, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9330777274311607, 0.8166666666666667, 'x[2] <= 0.13\ngini = 0.244\nsamples = 22\nvalue = [0, 2, 19, 0, 1, 0]'),
#  Text(0.9275008713837574, 0.7833333333333333, 'x[3] <= 2.15\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 0, 1, 0]'),
#  Text(0.9247124433600558, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.9302892994074591, 0.75, 'x[2] <= 0.11\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.9275008713837574, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9330777274311607, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.938654583478564, 0.7833333333333333, 'x[2] <= 0.265\ngini = 0.111\nsamples = 17\nvalue = [0, 1, 16, 0, 0, 0]'),
#  Text(0.9358661554548623, 0.75, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.9414430115022656, 0.75, 'x[2] <= 0.275\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.938654583478564, 0.7166666666666667, 'x[1] <= 0.9\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.9358661554548623, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9414430115022656, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9442314395259672, 0.7166666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9749041477866852, 0.8833333333333333, 'x[2] <= 0.655\ngini = 0.669\nsamples = 42\nvalue = [1, 3, 14, 19, 4, 1]'),
#  Text(0.9637504356918787, 0.85, 'x[1] <= 0.595\ngini = 0.612\nsamples = 37\nvalue = [1, 3, 14, 18, 1, 0]'),
#  Text(0.9553851516207738, 0.8166666666666667, 'x[2] <= 0.225\ngini = 0.418\nsamples = 15\nvalue = [0, 1, 3, 11, 0, 0]'),
#  Text(0.9525967235970721, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9581735796444755, 0.7833333333333333, 'x[2] <= 0.6\ngini = 0.357\nsamples = 14\nvalue = [0, 1, 2, 11, 0, 0]'),
#  Text(0.9553851516207738, 0.75, 'x[0] <= 12.2\ngini = 0.272\nsamples = 13\nvalue = [0, 1, 1, 11, 0, 0]'),
#  Text(0.9498082955733705, 0.7166666666666667, 'x[3] <= 2.15\ngini = 0.165\nsamples = 11\nvalue = [0, 1, 0, 10, 0, 0]'),
#  Text(0.9470198675496688, 0.6833333333333333, 'x[3] <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.9442314395259672, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9498082955733705, 0.65, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9525967235970721, 0.6833333333333333, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.9609620076681771, 0.7166666666666667, 'x[3] <= 2.35\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9581735796444755, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9637504356918787, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9609620076681771, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9721157197629836, 0.8166666666666667, 'x[0] <= 10.05\ngini = 0.636\nsamples = 22\nvalue = [1, 2, 11, 7, 1, 0]'),
#  Text(0.969327291739282, 0.7833333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9749041477866852, 0.7833333333333333, 'x[2] <= 0.27\ngini = 0.66\nsamples = 20\nvalue = [1, 2, 9, 7, 1, 0]'),
#  Text(0.969327291739282, 0.75, 'x[3] <= 3.05\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.9665388637155803, 0.7166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9721157197629836, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9804810038340885, 0.75, 'x[3] <= 1.6\ngini = 0.623\nsamples = 17\nvalue = [1, 1, 9, 5, 1, 0]'),
#  Text(0.9776925758103869, 0.7166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.9832694318577901, 0.7166666666666667, 'x[3] <= 1.85\ngini = 0.578\nsamples = 16\nvalue = [1, 0, 9, 5, 1, 0]'),
#  Text(0.9804810038340885, 0.6833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9860578598814919, 0.6833333333333333, 'x[2] <= 0.41\ngini = 0.56\nsamples = 15\nvalue = [1, 0, 9, 4, 1, 0]'),
#  Text(0.9832694318577901, 0.65, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9888462879051935, 0.65, 'x[0] <= 12.6\ngini = 0.645\nsamples = 11\nvalue = [1, 0, 5, 4, 1, 0]'),
#  Text(0.9832694318577901, 0.6166666666666667, 'x[1] <= 1.022\ngini = 0.667\nsamples = 6\nvalue = [1, 0, 1, 3, 1, 0]'),
#  Text(0.9804810038340885, 0.5833333333333334, 'x[3] <= 2.4\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 0, 3, 1, 0]'),
#  Text(0.9776925758103869, 0.55, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.9832694318577901, 0.55, 'x[2] <= 0.51\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.9804810038340885, 0.5166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9860578598814919, 0.5166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9860578598814919, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9944231439525967, 0.6166666666666667, 'x[1] <= 0.742\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.9916347159288951, 0.5833333333333334, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9972115719762984, 0.5833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9860578598814919, 0.85, 'x[0] <= 12.1\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 1, 3, 1]'),
#  Text(0.9832694318577901, 0.8166666666666667, 'x[2] <= 0.665\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.9804810038340885, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9860578598814919, 0.7833333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9888462879051935, 0.8166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]')]

# %%
predicciones = arbol.predict(X_test)

# %%
predicciones
# Out:
# array([5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 6, 6, 5, 6, 7, 7, 6, 7, 6, 7, 5, 8,
#        7, 5, 5, 6, 6, 6, 6, 6, 7, 6, 5, 6, 6, 6, 5, 5, 5, 6, 7, 7, 6, 6,
#        5, 7, 6, 7, 6, 6, 7, 6, 5, 5, 7, 4, 5, 7, 7, 5, 5, 5, 5, 7, 7, 7,
#        6, 6, 5, 6, 6, 6, 6, 6, 4, 6, 6, 5, 5, 4, 5, 5, 5, 5, 6, 6, 5, 6,
#        6, 5, 4, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 7, 5, 5, 5, 6, 5, 5, 5, 7,
#        7, 6, 7, 5, 6, 5, 7, 7, 5, 6, 5, 5, 6, 6, 7, 6, 5, 5, 6, 7, 6, 5,
#        5, 7, 6, 5, 7, 5, 6, 6, 5, 5, 5, 6, 5, 5, 6, 5, 3, 6, 5, 6, 6, 5,
#        5, 5, 6, 6, 6, 5, 5, 6, 6, 6, 7, 6, 5, 6, 6, 5, 5, 5, 5, 4, 7, 5,
#        5, 7, 5, 5, 6, 6, 6, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 5, 7, 7,
#        4, 4, 6, 6, 6, 6, 4, 6, 6, 5, 5, 5, 5, 5, 4, 6, 6, 5, 6, 6, 6, 6,
#        6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 5, 6, 5, 6, 6,
#        5, 6, 5, 6, 7, 5, 5, 5, 6, 5, 5, 6, 6, 6, 7, 7, 5, 5, 6, 6, 7, 5,
#        5, 6, 6, 7, 5, 6, 6, 5, 5, 5, 4, 4, 6, 5, 5, 5, 5, 7, 5, 5, 7, 5,
#        5, 7, 5, 6, 6, 6, 6, 6, 5, 7, 6, 5, 5, 5, 5, 6, 6, 6, 5, 7, 6, 6,
#        6, 4, 6, 5, 5, 5, 5, 5, 5, 5, 5, 5], dtype=int64)

# %%
# Examinamos la matriz de confusión
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4   5   6   7  8
# Actual
# 3             0  0   0   1   0  0
# 4             0  0   5   3   0  0
# 5             0  8  86  42   9  1
# 6             1  4  32  75  12  0
# 7             0  0   5  10  20  0
# 8             0  0   3   2   1  0

# %%
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.565625

# %%
precision = precision_score(y_test, predicciones, average='weighted')
precision
# Out:
# 0.5701212716906771

# %%
recall = recall_score(y_test, predicciones, average='weighted')
recall
# Out:
# 0.565625

# %%
f1 = f1_score(y_test, predicciones, average='weighted')
f1
# Out:
# 0.5662887460907521
